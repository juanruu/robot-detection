# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# ## Imports

# %%
import os
import cv2
import numpy as np
from tqdm import tqdm
from typing import List
from scipy.stats import norm
import matplotlib.pyplot as plt
import xml.etree.ElementTree as ET

# %% [markdown]
# ## Dataset

# %% [markdown]
# ### Dataset path
# Indicate here the path to your dataset.

# %%
DATASET_PATH = '../../datasets'
SEQUENCES = [x for x in os.listdir(DATASET_PATH) if os.path.isdir(os.path.join(DATASET_PATH, x))] # All sequences
# SEQUENCES = ['sequence1', 'sequence2', '...']  # Individual sequences

# %% [markdown]
# ### Load the data (frames & labels)

# %%
import os
import xml.etree.ElementTree as ET
from typing import List, Dict

def load_data_grouped(DATASET_PATH: str, sequences: List[str]) -> Dict:
    """
    Carga los datos agrupados por escenario ('sala', 'hall', 'aire_libre', 'pasillo_lab'),
    sin separar por nombre de secuencia. Todos los frames de un escenario se agrupan juntos
    y se renombran de forma ascendente continua: frame_1, frame_2, ...
    """
    grouped_data = {'sala_a': {},'sala_b': {},'sala_c': {} ,'hall': {}, 'aire_libre': {}, 'pasillo_lab': {}}
    frame_counters = {'sala_a': 1, 'sala_b': 1,'sala_c': 1,'hall': 1, 'aire_libre': 1, 'pasillo_lab': 1}

    for sequence in sorted(sequences):
        # Determinar grupo
        if sequence.startswith('sala_a'):
            group = 'sala_a'
        elif sequence.startswith( 'sala_b'):
            group = 'sala_b'
        elif sequence.startswith('sala_c'):
            group = 'sala_c'
        elif sequence.startswith('hall'):
            group = 'hall'
        elif sequence.startswith('aire_libre'):
            group = 'aire_libre'
        elif sequence.startswith('pasillo_lab'):
            group = 'pasillo_lab'
        else:
            continue

        labels_path = os.path.join(DATASET_PATH, sequence, 'labels')
        if not os.path.exists(labels_path):
            continue

        # Ordenar XMLs para mantener el orden temporal
        label_files = sorted(
            [f for f in os.listdir(labels_path) if f.lower().endswith('.xml')]
        )

        for label_filename in label_files:
            label_path = os.path.join(labels_path, label_filename)
            frame_filename, bboxes = load_labels(label_path)
            frame_path = os.path.join(DATASET_PATH, sequence, 'images', frame_filename)

            new_frame_name = f"frame_{frame_counters[group]}"
            frame_counters[group] += 1

            grouped_data[group][new_frame_name] = {
                'frame_path': frame_path,
                'bboxes': bboxes,
                'source_sequence': sequence  # opcional: para saber de qué carpeta viene
            }

    return grouped_data


def load_labels(xml_file: str):
    """Carga las etiquetas y bounding boxes desde un archivo XML (formato Pascal VOC)."""
    tree = ET.parse(xml_file)
    root = tree.getroot()

    frame_filename = root.find('filename').text
    all_bboxes = []
    for obj in root.iter('object'):
        x_min = int(obj.find("bndbox/xmin").text)
        y_min = int(obj.find("bndbox/ymin").text)
        x_max = int(obj.find("bndbox/xmax").text)
        y_max = int(obj.find("bndbox/ymax").text)
        all_bboxes.append([x_min, y_min, x_max, y_max])

    return frame_filename, all_bboxes

# %%
SEQUENCES
# Out:
# ['hall_473',
#  'sala_a_150',
#  'sala_c_452',
#  'aire_libre_682',
#  'sala_b_540',
#  'pasillo_lab_683',
#  'pasillo_lab_961',
#  'sala_c_167',
#  'aire_libre_941',
#  'sala_c_352',
#  'hall_116',
#  '.ipynb_checkpoints',
#  'sala_b_734',
#  'sala_b_775',
#  'sala_c_250',
#  'hall_266']

# %%
DATA = load_data_grouped(DATASET_PATH, SEQUENCES)

# %%
DATA
# Out:
# {'sala_a': {'frame_1': {'frame_path': '../../datasets/sala_a_150/images/frame_0020.jpg',
#    'bboxes': [[756, 327, 921, 488],
#     [922, 344, 1039, 434],
#     [652, 350, 676, 367],
#     [678, 349, 696, 364],
#     [713, 348, 727, 366]],
#    'source_sequence': 'sala_a_150'},
#   'frame_2': {'frame_path': '../../datasets/sala_a_150/images/frame_0040.jpg',
#    'bboxes': [[758, 340, 921, 494],
#     [922, 337, 1049, 437],
#     [651, 348, 673, 367],
#     [681, 350, 701, 366],
#     [717, 348, 736, 365]],
#    'source_sequence': 'sala_a_150'},
#   'frame_3': {'frame_path': '../../datasets/sala_a_150/images/frame_0060.jpg',
#    'bboxes': [[532, 339, 692, 493],
#     [834, 337, 959, 443],
#     [666, 350, 686, 367],
#     [698, 350, 713, 366]],
#    'source_sequence': 'sala_a_150'},
#   'frame_4': {'frame_path': '../../datasets/sala_a_150/images/frame_0080.jpg',
#    'bboxes': [[543, 346, 662, 440],
#     [778, 343, 869, 422],
#     [660, 350, 676, 366],
#     [676, 348, 689, 366]],
#    'source_sequence': 'sala_a_150'},
#   'frame_5': {'frame_path': '../../datasets/sala_a_150/images/frame_0100.jpg',
#    'bboxes': [[499, 343, 591, 417],
#     [773, 341, 865, 421],
#     [657, 350, 680, 367]],
#    'source_sequence': 'sala_a_150'},
#   'frame_6': {'frame_path': '../../datasets/sala_a_150/images/frame_0120.jpg',
#    'bboxes': [[254, 346, 376, 435],
#     [674, 343, 766, 417],
#     [641, 349, 661, 368]],
#    'source_sequence': 'sala_a_150'},
#   'frame_7': {'frame_path': '../../datasets/sala_a_150/images/frame_0140.jpg',
#    'bboxes': [[421, 341, 514, 422],
#     [736, 339, 838, 425],
#     [653, 347, 670, 368],
#     [622, 350, 642, 365]],
#    'source_sequence': 'sala_a_150'},
#   'frame_8': {'frame_path': '../../datasets/sala_a_150/images/frame_0160.jpg',
#    'bboxes': [[480, 343, 550, 410],
#     [737, 344, 834, 423],
#     [653, 348, 665, 367],
#     [630, 347, 648, 365],
#     [683, 348, 704, 365]],
#    'source_sequence': 'sala_a_150'},
#   'frame_9': {'frame_path': '../../datasets/sala_a_150/images/frame_0180.jpg',
#    'bboxes': [[494, 346, 556, 399],
#     [696, 343, 798, 434],
#     [640, 350, 661, 370],
#     [667, 347, 682, 365]],
#    'source_sequence': 'sala_a_150'},
#   'frame_10': {'frame_path': '../../datasets/sala_a_150/images/frame_0200.jpg',
#    'bboxes': [[486, 344, 549, 401],
#     [717, 342, 830, 452],
#     [624, 345, 650, 372]],
#    'source_sequence': 'sala_a_150'},
#   'frame_11': {'frame_path': '../../datasets/sala_a_150/images/frame_0220.jpg',
#    'bboxes': [[386, 342, 467, 415],
#     [652, 337, 762, 443],
#     [611, 347, 634, 372],
#     [639, 348, 656, 365]],
#    'source_sequence': 'sala_a_150'},
#   'frame_12': {'frame_path': '../../datasets/sala_a_150/images/frame_0240.jpg',
#    'bboxes': [[397, 339, 482, 424],
#     [756, 337, 869, 446],
#     [630, 347, 659, 381],
#     [684, 347, 703, 370]],
#    'source_sequence': 'sala_a_150'},
#   'frame_13': {'frame_path': '../../datasets/sala_a_150/images/frame_0260.jpg',
#    'bboxes': [[303, 333, 459, 452],
#     [760, 346, 891, 443],
#     [621, 351, 649, 378],
#     [652, 344, 679, 371]],
#    'source_sequence': 'sala_a_150'},
#   'frame_14': {'frame_path': '../../datasets/sala_a_150/images/frame_0280.jpg',
#    'bboxes': [[382, 330, 538, 461],
#     [735, 337, 883, 455],
#     [623, 349, 674, 390],
#     [672, 350, 699, 374]],
#    'source_sequence': 'sala_a_150'},
#   'frame_15': {'frame_path': '../../datasets/sala_a_150/images/frame_0300.jpg',
#    'bboxes': [[67, 284, 261, 430], [636, 278, 758, 428], [396, 297, 466, 344]],
#    'source_sequence': 'sala_a_150'},
#   'frame_16': {'frame_path': '../../datasets/sala_a_150/images/frame_0340.jpg',
#    'bboxes': [[336, 273, 596, 483]],
#    'source_sequence': 'sala_a_150'},
#   'frame_17': {'frame_path': '../../datasets/sala_a_150/images/frame_0360.jpg',
#    'bboxes': [[740, 301, 1016, 516], [936, 307, 1036, 406]],
#    'source_sequence': 'sala_a_150'},
#   'frame_18': {'frame_path': '../../datasets/sala_a_150/images/frame_0380.jpg',
#    'bboxes': [[276, 256, 543, 477], [626, 268, 725, 367]],
#    'source_sequence': 'sala_a_150'},
#   'frame_19': {'frame_path': '../../datasets/sala_a_150/images/frame_0400.jpg',
#    'bboxes': [[385, 210, 797, 612], [709, 252, 766, 312]],
#    'source_sequence': 'sala_a_150'},
#   'frame_20': {'frame_path': '../../datasets/sala_a_150/images/frame_0440.jpg',
#    'bboxes': [[515, 266, 683, 408], [474, 282, 522, 327]],
#    'source_sequence': 'sala_a_150'},
#   'frame_21': {'frame_path': '../../datasets/sala_a_150/images/frame_0460.jpg',
#    'bboxes': [[856, 268, 1052, 505],
#     [409, 294, 476, 358],
#     [587, 299, 624, 344],
#     [656, 298, 721, 363]],
#    'source_sequence': 'sala_a_150'},
#   'frame_22': {'frame_path': '../../datasets/sala_a_150/images/frame_0480.jpg',
#    'bboxes': [[66, 298, 179, 393], [482, 283, 674, 471]],
#    'source_sequence': 'sala_a_150'},
#   'frame_23': {'frame_path': '../../datasets/sala_a_150/images/frame_0500.jpg',
#    'bboxes': [[608, 298, 794, 502],
#     [816, 323, 880, 389],
#     [529, 310, 658, 440]],
#    'source_sequence': 'sala_a_150'},
#   'frame_24': {'frame_path': '../../datasets/sala_a_150/images/frame_0520.jpg',
#    'bboxes': [[414, 237, 599, 453]],
#    'source_sequence': 'sala_a_150'},
#   'frame_25': {'frame_path': '../../datasets/sala_a_150/images/frame_0560.jpg',
#    'bboxes': [[122, 197, 704, 720],
#     [762, 174, 1280, 720],
#     [101, 283, 179, 349]],
#    'source_sequence': 'sala_a_150'},
#   'frame_26': {'frame_path': '../../datasets/sala_a_150/images/frame_0580.jpg',
#    'bboxes': [[153, 260, 402, 510],
#     [489, 289, 580, 385],
#     [801, 295, 898, 390],
#     [929, 230, 1280, 720]],
#    'source_sequence': 'sala_a_150'},
#   'frame_27': {'frame_path': '../../datasets/sala_a_150/images/frame_0600.jpg',
#    'bboxes': [[388, 299, 491, 421],
#     [493, 310, 576, 390],
#     [984, 243, 1280, 720]],
#    'source_sequence': 'sala_a_150'},
#   'frame_28': {'frame_path': '../../datasets/sala_a_150/images/frame_0620.jpg',
#    'bboxes': [[701, 303, 804, 426],
#     [589, 310, 669, 379],
#     [656, 317, 701, 358]],
#    'source_sequence': 'sala_a_150'},
#   'frame_29': {'frame_path': '../../datasets/sala_a_150/images/frame_0640.jpg',
#    'bboxes': [[146, 223, 781, 711]],
#    'source_sequence': 'sala_a_150'},
#   'frame_30': {'frame_path': '../../datasets/sala_a_150/images/frame_0660.jpg',
#    'bboxes': [[1, 261, 417, 720],
#     [633, 292, 756, 429],
#     [1037, 297, 1203, 422],
#     [576, 309, 633, 357]],
#    'source_sequence': 'sala_a_150'},
#   'frame_31': {'frame_path': '../../datasets/sala_a_150/images/frame_0680.jpg',
#    'bboxes': [[569, 306, 633, 358], [848, 244, 1280, 720]],
#    'source_sequence': 'sala_a_150'},
#   'frame_32': {'frame_path': '../../datasets/sala_a_150/images/frame_0700.jpg',
#    'bboxes': [[562, 307, 592, 339],
#     [638, 307, 684, 355],
#     [962, 295, 1135, 432]],
#    'source_sequence': 'sala_a_150'},
#   'frame_33': {'frame_path': '../../datasets/sala_a_150/images/frame_0720.jpg',
#    'bboxes': [[587, 305, 617, 335],
#     [682, 310, 717, 341],
#     [861, 291, 1001, 430]],
#    'source_sequence': 'sala_a_150'},
#   'frame_34': {'frame_path': '../../datasets/sala_a_150/images/frame_0760.jpg',
#    'bboxes': [[669, 274, 827, 392],
#     [1153, 284, 1280, 449],
#     [308, 283, 342, 315],
#     [262, 284, 286, 312],
#     [2, 273, 215, 444]],
#    'source_sequence': 'sala_a_150'},
#   'frame_35': {'frame_path': '../../datasets/sala_a_150/images/frame_0780.jpg',
#    'bboxes': [[241, 277, 350, 389],
#     [543, 263, 727, 422],
#     [716, 275, 860, 410]],
#    'source_sequence': 'sala_a_150'},
#   'frame_36': {'frame_path': '../../datasets/sala_a_150/images/frame_0800.jpg',
#    'bboxes': [[676, 239, 962, 526], [564, 277, 636, 344]],
#    'source_sequence': 'sala_a_150'},
#   'frame_37': {'frame_path': '../../datasets/sala_a_150/images/frame_0820.jpg',
#    'bboxes': [[569, 280, 661, 352], [715, 280, 829, 388]],
#    'source_sequence': 'sala_a_150'},
#   'frame_38': {'frame_path': '../../datasets/sala_a_150/images/frame_0840.jpg',
#    'bboxes': [[577, 276, 677, 377]],
#    'source_sequence': 'sala_a_150'},
#   'frame_39': {'frame_path': '../../datasets/sala_a_150/images/frame_0880.jpg',
#    'bboxes': [[341, 255, 472, 381]],
#    'source_sequence': 'sala_a_150'},
#   'frame_40': {'frame_path': '../../datasets/sala_a_150/images/frame_0900.jpg',
#    'bboxes': [[603, 292, 697, 386]],
#    'source_sequence': 'sala_a_150'},
#   'frame_41': {'frame_path': '../../datasets/sala_a_150/images/frame_0920.jpg',
#    'bboxes': [[611, 290, 699, 378],
#     [576, 301, 595, 323],
#     [602, 300, 625, 330]],
#    'source_sequence': 'sala_a_150'},
#   'frame_42': {'frame_path': '../../datasets/sala_a_150/images/frame_0940.jpg',
#    'bboxes': [[590, 299, 613, 326], [640, 296, 720, 383]],
#    'source_sequence': 'sala_a_150'},
#   'frame_43': {'frame_path': '../../datasets/sala_a_150/images/frame_0960.jpg',
#    'bboxes': [[511, 292, 645, 403]],
#    'source_sequence': 'sala_a_150'},
#   'frame_44': {'frame_path': '../../datasets/sala_a_150/images/frame_0980.jpg',
#    'bboxes': [[584, 313, 763, 469], [571, 332, 602, 360]],
#    'source_sequence': 'sala_a_150'},
#   'frame_45': {'frame_path': '../../datasets/sala_a_150/images/frame_1000.jpg',
#    'bboxes': [[561, 332, 595, 368], [631, 310, 804, 454]],
#    'source_sequence': 'sala_a_150'},
#   'frame_46': {'frame_path': '../../datasets/sala_a_150/images/frame_1020.jpg',
#    'bboxes': [[459, 304, 648, 477], [620, 325, 654, 361]],
#    'source_sequence': 'sala_a_150'},
#   'frame_47': {'frame_path': '../../datasets/sala_a_150/images/frame_1040.jpg',
#    'bboxes': [[273, 263, 670, 661], [589, 324, 626, 365]],
#    'source_sequence': 'sala_a_150'},
#   'frame_48': {'frame_path': '../../datasets/sala_a_150/images/frame_1060.jpg',
#    'bboxes': [[497, 322, 563, 386]],
#    'source_sequence': 'sala_a_150'},
#   'frame_49': {'frame_path': '../../datasets/sala_a_150/images/frame_1080.jpg',
#    'bboxes': [[670, 295, 752, 383]],
#    'source_sequence': 'sala_a_150'},
#   'frame_50': {'frame_path': '../../datasets/sala_a_150/images/frame_1100.jpg',
#    'bboxes': [[523, 317, 685, 478], [656, 335, 696, 377]],
#    'source_sequence': 'sala_a_150'},
#   'frame_51': {'frame_path': '../../datasets/sala_a_150/images/frame_1120.jpg',
#    'bboxes': [[222, 313, 396, 478], [675, 332, 709, 371]],
#    'source_sequence': 'sala_a_150'},
#   'frame_52': {'frame_path': '../../datasets/sala_a_150/images/frame_1140.jpg',
#    'bboxes': [[517, 290, 684, 461], [787, 309, 825, 351]],
#    'source_sequence': 'sala_a_150'},
#   'frame_53': {'frame_path': '../../datasets/sala_a_150/images/frame_1160.jpg',
#    'bboxes': [[329, 272, 709, 617]],
#    'source_sequence': 'sala_a_150'},
#   'frame_54': {'frame_path': '../../datasets/sala_a_150/images/frame_1180.jpg',
#    'bboxes': [[656, 271, 983, 568], [589, 304, 643, 349]],
#    'source_sequence': 'sala_a_150'},
#   'frame_55': {'frame_path': '../../datasets/sala_a_150/images/frame_1220.jpg',
#    'bboxes': [[442, 299, 584, 427], [246, 309, 304, 347]],
#    'source_sequence': 'sala_a_150'},
#   'frame_56': {'frame_path': '../../datasets/sala_a_150/images/frame_1240.jpg',
#    'bboxes': [[257, 317, 381, 433]],
#    'source_sequence': 'sala_a_150'},
#   'frame_57': {'frame_path': '../../datasets/sala_a_150/images/frame_1260.jpg',
#    'bboxes': [[641, 363, 822, 495], [646, 355, 693, 414]],
#    'source_sequence': 'sala_a_150'},
#   'frame_58': {'frame_path': '../../datasets/sala_a_150/images/frame_1280.jpg',
#    'bboxes': [[638, 348, 866, 538],
#     [484, 353, 529, 403],
#     [549, 358, 604, 410]],
#    'source_sequence': 'sala_a_150'},
#   'frame_59': {'frame_path': '../../datasets/sala_a_150/images/frame_1300.jpg',
#    'bboxes': [[511, 357, 556, 401],
#     [575, 357, 618, 404],
#     [669, 345, 848, 490]],
#    'source_sequence': 'sala_a_150'},
#   'frame_60': {'frame_path': '../../datasets/sala_a_150/images/frame_1320.jpg',
#    'bboxes': [[683, 342, 826, 497],
#     [644, 350, 682, 394],
#     [482, 354, 532, 408]],
#    'source_sequence': 'sala_a_150'},
#   'frame_61': {'frame_path': '../../datasets/sala_a_150/images/frame_1340.jpg',
#    'bboxes': [[718, 166, 1131, 567],
#     [386, 225, 461, 303],
#     [629, 229, 671, 275]],
#    'source_sequence': 'sala_a_150'},
#   'frame_62': {'frame_path': '../../datasets/sala_a_150/images/frame_1360.jpg',
#    'bboxes': [[576, 240, 619, 281],
#     [965, 157, 1280, 691],
#     [10, 242, 115, 335]],
#    'source_sequence': 'sala_a_150'},
#   'frame_63': {'frame_path': '../../datasets/sala_a_150/images/frame_1380.jpg',
#    'bboxes': [[113, 304, 204, 383], [669, 309, 713, 354]],
#    'source_sequence': 'sala_a_150'},
#   'frame_64': {'frame_path': '../../datasets/sala_a_150/images/frame_1400.jpg',
#    'bboxes': [[611, 307, 656, 352]],
#    'source_sequence': 'sala_a_150'},
#   'frame_65': {'frame_path': '../../datasets/sala_a_150/images/frame_1420.jpg',
#    'bboxes': [[565, 310, 619, 357]],
#    'source_sequence': 'sala_a_150'},
#   'frame_66': {'frame_path': '../../datasets/sala_a_150/images/frame_1440.jpg',
#    'bboxes': [[676, 303, 751, 378]],
#    'source_sequence': 'sala_a_150'},
#   'frame_67': {'frame_path': '../../datasets/sala_a_150/images/frame_1460.jpg',
#    'bboxes': [[601, 298, 676, 384]],
#    'source_sequence': 'sala_a_150'},
#   'frame_68': {'frame_path': '../../datasets/sala_a_150/images/frame_1480.jpg',
#    'bboxes': [[553, 302, 634, 380]],
#    'source_sequence': 'sala_a_150'},
#   'frame_69': {'frame_path': '../../datasets/sala_a_150/images/frame_1500.jpg',
#    'bboxes': [[676, 322, 745, 397]],
#    'source_sequence': 'sala_a_150'},
#   'frame_70': {'frame_path': '../../datasets/sala_a_150/images/frame_1520.jpg',
#    'bboxes': [[518, 323, 595, 390]],
#    'source_sequence': 'sala_a_150'},
#   'frame_71': {'frame_path': '../../datasets/sala_a_150/images/frame_1540.jpg',
#    'bboxes': [[538, 322, 643, 421]],
#    'source_sequence': 'sala_a_150'},
#   'frame_72': {'frame_path': '../../datasets/sala_a_150/images/frame_1560.jpg',
#    'bboxes': [[762, 325, 838, 410]],
#    'source_sequence': 'sala_a_150'},
#   'frame_73': {'frame_path': '../../datasets/sala_a_150/images/frame_1580.jpg',
#    'bboxes': [[780, 323, 889, 415]],
#    'source_sequence': 'sala_a_150'},
#   'frame_74': {'frame_path': '../../datasets/sala_a_150/images/frame_1600.jpg',
#    'bboxes': [[675, 318, 809, 418]],
#    'source_sequence': 'sala_a_150'},
#   'frame_75': {'frame_path': '../../datasets/sala_a_150/images/frame_1620.jpg',
#    'bboxes': [[476, 321, 571, 410]],
#    'source_sequence': 'sala_a_150'},
#   'frame_76': {'frame_path': '../../datasets/sala_a_150/images/frame_1640.jpg',
#    'bboxes': [[496, 321, 572, 387]],
#    'source_sequence': 'sala_a_150'},
#   'frame_77': {'frame_path': '../../datasets/sala_a_150/images/frame_1660.jpg',
#    'bboxes': [[630, 317, 711, 390]],
#    'source_sequence': 'sala_a_150'},
#   'frame_78': {'frame_path': '../../datasets/sala_a_150/images/frame_1680.jpg',
#    'bboxes': [[605, 311, 741, 444]],
#    'source_sequence': 'sala_a_150'},
#   'frame_79': {'frame_path': '../../datasets/sala_a_150/images/frame_1700.jpg',
#    'bboxes': [[1, 223, 780, 720]],
#    'source_sequence': 'sala_a_150'},
#   'frame_80': {'frame_path': '../../datasets/sala_a_150/images/frame_1720.jpg',
#    'bboxes': [[253, 291, 565, 545]],
#    'source_sequence': 'sala_a_150'},
#   'frame_81': {'frame_path': '../../datasets/sala_a_150/images/frame_1740.jpg',
#    'bboxes': [[442, 318, 557, 428]],
#    'source_sequence': 'sala_a_150'},
#   'frame_82': {'frame_path': '../../datasets/sala_a_150/images/frame_1760.jpg',
#    'bboxes': [[565, 316, 668, 411]],
#    'source_sequence': 'sala_a_150'},
#   'frame_83': {'frame_path': '../../datasets/sala_a_150/images/frame_1780.jpg',
#    'bboxes': [[565, 316, 668, 410]],
#    'source_sequence': 'sala_a_150'},
#   'frame_84': {'frame_path': '../../datasets/sala_a_150/images/frame_1800.jpg',
#    'bboxes': [[611, 311, 716, 422]],
#    'source_sequence': 'sala_a_150'},
#   'frame_85': {'frame_path': '../../datasets/sala_a_150/images/frame_1820.jpg',
#    'bboxes': [[635, 317, 748, 418]],
#    'source_sequence': 'sala_a_150'},
#   'frame_86': {'frame_path': '../../datasets/sala_a_150/images/frame_1840.jpg',
#    'bboxes': [[641, 320, 755, 417]],
#    'source_sequence': 'sala_a_150'},
#   'frame_87': {'frame_path': '../../datasets/sala_a_150/images/frame_1860.jpg',
#    'bboxes': [[644, 311, 760, 422]],
#    'source_sequence': 'sala_a_150'}},
#  'sala_b': {'frame_1': {'frame_path': '../../datasets/sala_b_540/images/frame_0020.jpg',
#    'bboxes': [[577, 450, 819, 715], [3, 375, 139, 667]],
#    'source_sequence': 'sala_b_540'},
#   'frame_2': {'frame_path': '../../datasets/sala_b_540/images/frame_0040.jpg',
#    'bboxes': [[763, 401, 1114, 720], [17, 406, 183, 608]],
#    'source_sequence': 'sala_b_540'},
#   'frame_3': {'frame_path': '../../datasets/sala_b_540/images/frame_0100.jpg',
#    'bboxes': [[4, 623, 54, 720]],
#    'source_sequence': 'sala_b_540'},
#   'frame_4': {'frame_path': '../../datasets/sala_b_540/images/frame_0520.jpg',
#    'bboxes': [[1067, 339, 1138, 401]],
#    'source_sequence': 'sala_b_540'},
#   'frame_5': {'frame_path': '../../datasets/sala_b_540/images/frame_0540.jpg',
#    'bboxes': [[678, 283, 727, 338],
#     [722, 292, 779, 341],
#     [959, 284, 1045, 360]],
#    'source_sequence': 'sala_b_540'},
#   'frame_6': {'frame_path': '../../datasets/sala_b_540/images/frame_0560.jpg',
#    'bboxes': [[423, 296, 468, 351],
#     [455, 300, 509, 352],
#     [544, 303, 590, 348]],
#    'source_sequence': 'sala_b_540'},
#   'frame_7': {'frame_path': '../../datasets/sala_b_540/images/frame_0580.jpg',
#    'bboxes': [[480, 302, 530, 349],
#     [440, 298, 499, 353],
#     [430, 294, 483, 352]],
#    'source_sequence': 'sala_b_540'},
#   'frame_8': {'frame_path': '../../datasets/sala_b_540/images/frame_0600.jpg',
#    'bboxes': [[569, 299, 645, 368],
#     [427, 294, 493, 357],
#     [404, 299, 447, 356],
#     [248, 297, 309, 354]],
#    'source_sequence': 'sala_b_540'},
#   'frame_9': {'frame_path': '../../datasets/sala_b_540/images/frame_0620.jpg',
#    'bboxes': [[712, 384, 811, 475],
#     [549, 395, 627, 459],
#     [602, 387, 655, 448]],
#    'source_sequence': 'sala_b_540'},
#   'frame_10': {'frame_path': '../../datasets/sala_b_540/images/frame_0640.jpg',
#    'bboxes': [[577, 468, 689, 560],
#     [542, 467, 596, 529],
#     [460, 467, 515, 534],
#     [349, 465, 455, 555]],
#    'source_sequence': 'sala_b_540'},
#   'frame_11': {'frame_path': '../../datasets/sala_b_540/images/frame_0660.jpg',
#    'bboxes': [[600, 426, 724, 536],
#     [555, 435, 618, 513],
#     [322, 431, 496, 579]],
#    'source_sequence': 'sala_b_540'},
#   'frame_12': {'frame_path': '../../datasets/sala_b_540/images/frame_0680.jpg',
#    'bboxes': [[195, 403, 466, 651],
#     [602, 435, 665, 513],
#     [677, 429, 764, 517],
#     [757, 429, 865, 530]],
#    'source_sequence': 'sala_b_540'},
#   'frame_13': {'frame_path': '../../datasets/sala_b_540/images/frame_0700.jpg',
#    'bboxes': [[275, 424, 435, 553],
#     [500, 433, 562, 507],
#     [559, 430, 636, 512],
#     [628, 432, 714, 521]],
#    'source_sequence': 'sala_b_540'},
#   'frame_14': {'frame_path': '../../datasets/sala_b_540/images/frame_0720.jpg',
#    'bboxes': [[130, 421, 320, 561],
#     [284, 434, 352, 501],
#     [416, 432, 525, 516],
#     [549, 427, 657, 526]],
#    'source_sequence': 'sala_b_540'},
#   'frame_15': {'frame_path': '../../datasets/sala_b_540/images/frame_0740.jpg',
#    'bboxes': [[287, 416, 456, 570],
#     [411, 436, 475, 497],
#     [515, 430, 575, 503],
#     [553, 431, 633, 529],
#     [667, 431, 749, 525]],
#    'source_sequence': 'sala_b_540'},
#   'frame_16': {'frame_path': '../../datasets/sala_b_540/images/frame_0760.jpg',
#    'bboxes': [[174, 400, 372, 591],
#     [406, 437, 554, 557],
#     [607, 425, 686, 529],
#     [792, 422, 915, 566]],
#    'source_sequence': 'sala_b_540'},
#   'frame_17': {'frame_path': '../../datasets/sala_b_540/images/frame_0780.jpg',
#    'bboxes': [[542, 424, 710, 602],
#     [661, 418, 747, 549],
#     [365, 426, 481, 537],
#     [230, 410, 390, 557]],
#    'source_sequence': 'sala_b_540'},
#   'frame_18': {'frame_path': '../../datasets/sala_b_540/images/frame_0800.jpg',
#    'bboxes': [[327, 402, 480, 569],
#     [445, 435, 509, 520],
#     [494, 444, 538, 501],
#     [660, 436, 742, 529]],
#    'source_sequence': 'sala_b_540'},
#   'frame_19': {'frame_path': '../../datasets/sala_b_540/images/frame_0820.jpg',
#    'bboxes': [[307, 418, 475, 579],
#     [495, 441, 592, 518],
#     [600, 437, 676, 520],
#     [632, 435, 687, 501],
#     [778, 420, 876, 538]],
#    'source_sequence': 'sala_b_540'},
#   'frame_20': {'frame_path': '../../datasets/sala_b_540/images/frame_0840.jpg',
#    'bboxes': [[62, 390, 255, 652],
#     [362, 435, 502, 564],
#     [454, 435, 592, 581],
#     [651, 433, 712, 508]],
#    'source_sequence': 'sala_b_540'},
#   'frame_21': {'frame_path': '../../datasets/sala_b_540/images/frame_0860.jpg',
#    'bboxes': [[23, 417, 275, 627],
#     [303, 417, 462, 588],
#     [197, 425, 329, 570],
#     [651, 432, 701, 501]],
#    'source_sequence': 'sala_b_540'},
#   'frame_22': {'frame_path': '../../datasets/sala_b_540/images/frame_0880.jpg',
#    'bboxes': [[421, 423, 576, 561],
#     [539, 433, 654, 547],
#     [691, 443, 732, 492]],
#    'source_sequence': 'sala_b_540'},
#   'frame_23': {'frame_path': '../../datasets/sala_b_540/images/frame_0900.jpg',
#    'bboxes': [[491, 430, 612, 564],
#     [551, 427, 694, 603],
#     [646, 428, 784, 573],
#     [769, 447, 813, 502]],
#    'source_sequence': 'sala_b_540'},
#   'frame_24': {'frame_path': '../../datasets/sala_b_540/images/frame_0920.jpg',
#    'bboxes': [[1, 414, 167, 698],
#     [323, 424, 443, 589],
#     [451, 435, 583, 574],
#     [710, 448, 767, 504]],
#    'source_sequence': 'sala_b_540'},
#   'frame_25': {'frame_path': '../../datasets/sala_b_540/images/frame_0940.jpg',
#    'bboxes': [[56, 431, 286, 720],
#     [356, 411, 635, 720],
#     [736, 434, 794, 506],
#     [298, 430, 369, 497]],
#    'source_sequence': 'sala_b_540'},
#   'frame_26': {'frame_path': '../../datasets/sala_b_540/images/frame_0960.jpg',
#    'bboxes': [[174, 373, 611, 720], [632, 441, 694, 501]],
#    'source_sequence': 'sala_b_540'},
#   'frame_27': {'frame_path': '../../datasets/sala_b_540/images/frame_0980.jpg',
#    'bboxes': [[452, 437, 507, 492], [626, 441, 672, 494], [1, 368, 328, 712]],
#    'source_sequence': 'sala_b_540'},
#   'frame_28': {'frame_path': '../../datasets/sala_b_540/images/frame_1000.jpg',
#    'bboxes': [[373, 423, 546, 580],
#     [547, 438, 602, 492],
#     [607, 444, 653, 493]],
#    'source_sequence': 'sala_b_540'},
#   'frame_29': {'frame_path': '../../datasets/sala_b_540/images/frame_1020.jpg',
#    'bboxes': [[341, 411, 500, 569],
#     [541, 435, 607, 506],
#     [652, 441, 699, 497]],
#    'source_sequence': 'sala_b_540'},
#   'frame_30': {'frame_path': '../../datasets/sala_b_540/images/frame_1040.jpg',
#    'bboxes': [[323, 422, 462, 547],
#     [540, 429, 627, 529],
#     [660, 439, 710, 500]],
#    'source_sequence': 'sala_b_540'},
#   'frame_31': {'frame_path': '../../datasets/sala_b_540/images/frame_1060.jpg',
#    'bboxes': [[1, 399, 539, 717], [693, 411, 862, 578], [661, 441, 712, 501]],
#    'source_sequence': 'sala_b_540'},
#   'frame_32': {'frame_path': '../../datasets/sala_b_540/images/frame_1080.jpg',
#    'bboxes': [[644, 435, 897, 645],
#     [398, 430, 604, 639],
#     [581, 444, 634, 501],
#     [388, 438, 509, 539]],
#    'source_sequence': 'sala_b_540'},
#   'frame_33': {'frame_path': '../../datasets/sala_b_540/images/frame_1100.jpg',
#    'bboxes': [[576, 433, 711, 563],
#     [730, 436, 865, 582],
#     [846, 437, 1130, 650]],
#    'source_sequence': 'sala_b_540'},
#   'frame_34': {'frame_path': '../../datasets/sala_b_540/images/frame_1120.jpg',
#    'bboxes': [[535, 423, 1088, 720],
#     [645, 446, 716, 518],
#     [191, 422, 500, 677]],
#    'source_sequence': 'sala_b_540'},
#   'frame_35': {'frame_path': '../../datasets/sala_b_540/images/frame_1140.jpg',
#    'bboxes': [[3, 371, 359, 720],
#     [866, 390, 1179, 645],
#     [679, 441, 770, 526],
#     [727, 439, 781, 508]],
#    'source_sequence': 'sala_b_540'},
#   'frame_36': {'frame_path': '../../datasets/sala_b_540/images/frame_1160.jpg',
#    'bboxes': [[448, 423, 842, 720], [709, 439, 775, 515]],
#    'source_sequence': 'sala_b_540'},
#   'frame_37': {'frame_path': '../../datasets/sala_b_540/images/frame_1180.jpg',
#    'bboxes': [[460, 421, 776, 702]],
#    'source_sequence': 'sala_b_540'},
#   'frame_38': {'frame_path': '../../datasets/sala_b_540/images/frame_1200.jpg',
#    'bboxes': [[435, 405, 920, 720]],
#    'source_sequence': 'sala_b_540'},
#   'frame_39': {'frame_path': '../../datasets/sala_b_540/images/frame_1220.jpg',
#    'bboxes': [[437, 445, 737, 664],
#     [694, 445, 767, 527],
#     [460, 443, 533, 510]],
#    'source_sequence': 'sala_b_540'},
#   'frame_40': {'frame_path': '../../datasets/sala_b_540/images/frame_1240.jpg',
#    'bboxes': [[447, 397, 678, 620],
#     [879, 416, 997, 546],
#     [369, 444, 450, 517]],
#    'source_sequence': 'sala_b_540'},
#   'frame_41': {'frame_path': '../../datasets/sala_b_540/images/frame_1260.jpg',
#    'bboxes': [[544, 438, 710, 581],
#     [161, 422, 322, 566],
#     [103, 441, 189, 506]],
#    'source_sequence': 'sala_b_540'},
#   'frame_42': {'frame_path': '../../datasets/sala_b_540/images/frame_1280.jpg',
#    'bboxes': [[256, 418, 757, 720], [242, 410, 421, 567]],
#    'source_sequence': 'sala_b_540'},
#   'frame_43': {'frame_path': '../../datasets/sala_b_540/images/frame_1300.jpg',
#    'bboxes': [[350, 402, 816, 720], [88, 412, 237, 557]],
#    'source_sequence': 'sala_b_540'},
#   'frame_44': {'frame_path': '../../datasets/sala_b_540/images/frame_1320.jpg',
#    'bboxes': [[387, 433, 510, 557],
#     [1070, 383, 1280, 668],
#     [12, 416, 95, 528]],
#    'source_sequence': 'sala_b_540'},
#   'frame_45': {'frame_path': '../../datasets/sala_b_540/images/frame_1340.jpg',
#    'bboxes': [[301, 402, 441, 581], [52, 411, 225, 568]],
#    'source_sequence': 'sala_b_540'},
#   'frame_46': {'frame_path': '../../datasets/sala_b_540/images/frame_1540.jpg',
#    'bboxes': [[647, 141, 783, 251], [386, 138, 469, 216], [10, 151, 147, 321]],
#    'source_sequence': 'sala_b_540'},
#   'frame_47': {'frame_path': '../../datasets/sala_b_540/images/frame_1560.jpg',
#    'bboxes': [[446, 245, 597, 364]],
#    'source_sequence': 'sala_b_540'},
#   'frame_48': {'frame_path': '../../datasets/sala_b_540/images/frame_1580.jpg',
#    'bboxes': [[228, 223, 514, 446],
#     [459, 221, 599, 371],
#     [755, 191, 1280, 717],
#     [29, 249, 85, 310]],
#    'source_sequence': 'sala_b_540'},
#   'frame_49': {'frame_path': '../../datasets/sala_b_540/images/frame_1600.jpg',
#    'bboxes': [[242, 146, 742, 668],
#     [570, 183, 800, 418],
#     [156, 257, 194, 303]],
#    'source_sequence': 'sala_b_540'},
#   'frame_50': {'frame_path': '../../datasets/sala_b_540/images/frame_1620.jpg',
#    'bboxes': [[142, 177, 572, 556],
#     [514, 207, 684, 383],
#     [766, 155, 1107, 494],
#     [1114, 217, 1280, 439],
#     [158, 254, 210, 304]],
#    'source_sequence': 'sala_b_540'},
#   'frame_51': {'frame_path': '../../datasets/sala_b_540/images/frame_1640.jpg',
#    'bboxes': [[175, 151, 539, 519],
#     [616, 209, 768, 371],
#     [1021, 223, 1280, 443],
#     [1008, 231, 1202, 363],
#     [225, 260, 276, 307]],
#    'source_sequence': 'sala_b_540'},
#   'frame_52': {'frame_path': '../../datasets/sala_b_540/images/frame_1660.jpg',
#    'bboxes': [[725, 144, 1106, 613],
#     [1122, 249, 1274, 379],
#     [772, 251, 912, 355],
#     [385, 243, 453, 309]],
#    'source_sequence': 'sala_b_540'},
#   'frame_53': {'frame_path': '../../datasets/sala_b_540/images/frame_1680.jpg',
#    'bboxes': [[705, 115, 1091, 606],
#     [732, 242, 873, 341],
#     [439, 257, 482, 316]],
#    'source_sequence': 'sala_b_540'},
#   'frame_54': {'frame_path': '../../datasets/sala_b_540/images/frame_1700.jpg',
#    'bboxes': [[727, 189, 1161, 586],
#     [642, 231, 781, 362],
#     [409, 249, 494, 325]],
#    'source_sequence': 'sala_b_540'},
#   'frame_55': {'frame_path': '../../datasets/sala_b_540/images/frame_1720.jpg',
#    'bboxes': [[479, 242, 600, 355],
#     [731, 246, 803, 331],
#     [1059, 234, 1280, 473]],
#    'source_sequence': 'sala_b_540'},
#   'frame_56': {'frame_path': '../../datasets/sala_b_540/images/frame_1740.jpg',
#    'bboxes': [[329, 238, 425, 346],
#     [492, 240, 595, 339],
#     [796, 248, 878, 338],
#     [1010, 206, 1222, 401],
#     [1097, 203, 1257, 379]],
#    'source_sequence': 'sala_b_540'},
#   'frame_57': {'frame_path': '../../datasets/sala_b_540/images/frame_1760.jpg',
#    'bboxes': [[550, 230, 655, 360],
#     [803, 237, 902, 341],
#     [1025, 228, 1196, 386],
#     [1171, 247, 1280, 391],
#     [272, 237, 375, 334]],
#    'source_sequence': 'sala_b_540'},
#   'frame_58': {'frame_path': '../../datasets/sala_b_540/images/frame_1780.jpg',
#    'bboxes': [[245, 230, 350, 339],
#     [481, 225, 629, 378],
#     [891, 236, 1035, 380],
#     [1042, 218, 1172, 386],
#     [1129, 219, 1277, 382]],
#    'source_sequence': 'sala_b_540'},
#   'frame_59': {'frame_path': '../../datasets/sala_b_540/images/frame_1800.jpg',
#    'bboxes': [[191, 358, 431, 581],
#     [527, 377, 762, 621],
#     [716, 382, 816, 521],
#     [788, 388, 920, 516]],
#    'source_sequence': 'sala_b_540'},
#   'frame_60': {'frame_path': '../../datasets/sala_b_540/images/frame_1820.jpg',
#    'bboxes': [[9, 346, 265, 580],
#     [249, 341, 607, 683],
#     [559, 390, 664, 528],
#     [712, 386, 856, 524]],
#    'source_sequence': 'sala_b_540'},
#   'frame_61': {'frame_path': '../../datasets/sala_b_540/images/frame_1840.jpg',
#    'bboxes': [[7, 369, 272, 608],
#     [222, 320, 614, 714],
#     [566, 378, 681, 538],
#     [716, 376, 876, 528]],
#    'source_sequence': 'sala_b_540'},
#   'frame_62': {'frame_path': '../../datasets/sala_b_540/images/frame_1860.jpg',
#    'bboxes': [[29, 307, 599, 720], [571, 377, 720, 575], [767, 373, 976, 572]],
#    'source_sequence': 'sala_b_540'},
#   'frame_63': {'frame_path': '../../datasets/sala_b_540/images/frame_1880.jpg',
#    'bboxes': [[7, 111, 641, 720], [562, 360, 724, 581], [776, 369, 990, 567]],
#    'source_sequence': 'sala_b_540'},
#   'frame_64': {'frame_path': '../../datasets/sala_b_540/images/frame_1900.jpg',
#    'bboxes': [[1, 350, 241, 720], [404, 397, 557, 557], [617, 387, 796, 554]],
#    'source_sequence': 'sala_b_540'},
#   'frame_65': {'frame_path': '../../datasets/sala_b_540/images/frame_1920.jpg',
#    'bboxes': [[4, 357, 243, 720], [405, 377, 556, 557], [618, 381, 791, 558]],
#    'source_sequence': 'sala_b_540'},
#   'frame_66': {'frame_path': '../../datasets/sala_b_540/images/frame_1940.jpg',
#    'bboxes': [[251, 379, 451, 567], [512, 381, 690, 563]],
#    'source_sequence': 'sala_b_540'},
#   'frame_67': {'frame_path': '../../datasets/sala_b_540/images/frame_1960.jpg',
#    'bboxes': [[8, 378, 239, 637], [445, 343, 762, 686]],
#    'source_sequence': 'sala_b_540'},
#   'frame_68': {'frame_path': '../../datasets/sala_b_540/images/frame_2020.jpg',
#    'bboxes': [[2, 349, 369, 720]],
#    'source_sequence': 'sala_b_540'},
#   'frame_69': {'frame_path': '../../datasets/sala_b_540/images/frame_2040.jpg',
#    'bboxes': [[403, 347, 737, 707]],
#    'source_sequence': 'sala_b_540'},
#   'frame_70': {'frame_path': '../../datasets/sala_b_540/images/frame_2060(1).jpg',
#    'bboxes': [[414, 339, 717, 671]],
#    'source_sequence': 'sala_b_540'},
#   'frame_71': {'frame_path': '../../datasets/sala_b_540/images/frame_2060.jpg',
#    'bboxes': [[62, 23, 304, 259], [447, 46, 530, 143], [572, 61, 623, 123]],
#    'source_sequence': 'sala_b_540'},
#   'frame_72': {'frame_path': '../../datasets/sala_b_540/images/frame_2080(1).jpg',
#    'bboxes': [[442, 350, 716, 641]],
#    'source_sequence': 'sala_b_540'},
#   'frame_73': {'frame_path': '../../datasets/sala_b_540/images/frame_2080.jpg',
#    'bboxes': [[36, 39, 272, 269], [527, 57, 611, 148]],
#    'source_sequence': 'sala_b_540'},
#   'frame_74': {'frame_path': '../../datasets/sala_b_540/images/frame_2100.jpg',
#    'bboxes': [[98, 218, 315, 427], [723, 235, 830, 332], [589, 225, 638, 290]],
#    'source_sequence': 'sala_b_540'},
#   'frame_75': {'frame_path': '../../datasets/sala_b_540/images/frame_2360.jpg',
#    'bboxes': [[898, 330, 1049, 464],
#     [832, 338, 892, 390],
#     [735, 344, 799, 390]],
#    'source_sequence': 'sala_b_540'},
#   'frame_76': {'frame_path': '../../datasets/sala_b_540/images/frame_2380.jpg',
#    'bboxes': [[562, 289, 676, 430],
#     [501, 317, 552, 368],
#     [396, 316, 447, 372]],
#    'source_sequence': 'sala_b_540'},
#   'frame_77': {'frame_path': '../../datasets/sala_b_540/images/frame_2400.jpg',
#    'bboxes': [[83, 358, 245, 524], [7, 392, 85, 450]],
#    'source_sequence': 'sala_b_540'},
#   'frame_78': {'frame_path': '../../datasets/sala_b_540/images/frame_2420.jpg',
#    'bboxes': [[636, 428, 756, 550],
#     [577, 435, 628, 484],
#     [471, 431, 527, 485]],
#    'source_sequence': 'sala_b_540'},
#   'frame_79': {'frame_path': '../../datasets/sala_b_540/images/frame_2440.jpg',
#    'bboxes': [[635, 407, 755, 553],
#     [575, 430, 625, 484],
#     [470, 427, 528, 485]],
#    'source_sequence': 'sala_b_540'},
#   'frame_80': {'frame_path': '../../datasets/sala_b_540/images/frame_2460.jpg',
#    'bboxes': [[468, 397, 613, 589], [403, 429, 458, 489]],
#    'source_sequence': 'sala_b_540'},
#   'frame_81': {'frame_path': '../../datasets/sala_b_540/images/frame_2480.jpg',
#    'bboxes': [[624, 398, 776, 582],
#     [565, 424, 621, 487],
#     [459, 425, 515, 485]],
#    'source_sequence': 'sala_b_540'},
#   'frame_82': {'frame_path': '../../datasets/sala_b_540/images/frame_2500.jpg',
#    'bboxes': [[526, 381, 718, 633],
#     [535, 434, 600, 491],
#     [409, 425, 477, 488]],
#    'source_sequence': 'sala_b_540'},
#   'frame_83': {'frame_path': '../../datasets/sala_b_540/images/frame_2520.jpg',
#    'bboxes': [[494, 365, 730, 678], [409, 418, 466, 495]],
#    'source_sequence': 'sala_b_540'},
#   'frame_84': {'frame_path': '../../datasets/sala_b_540/images/frame_2540.jpg',
#    'bboxes': [[883, 220, 1279, 720],
#     [576, 424, 640, 498],
#     [440, 416, 494, 495]],
#    'source_sequence': 'sala_b_540'},
#   'frame_85': {'frame_path': '../../datasets/sala_b_540/images/frame_2560.jpg',
#    'bboxes': [[445, 416, 507, 498], [587, 419, 664, 499]],
#    'source_sequence': 'sala_b_540'},
#   'frame_86': {'frame_path': '../../datasets/sala_b_540/images/frame_2580.jpg',
#    'bboxes': [[304, 414, 416, 507], [492, 424, 584, 510]],
#    'source_sequence': 'sala_b_540'},
#   'frame_87': {'frame_path': '../../datasets/sala_b_540/images/frame_2600.jpg',
#    'bboxes': [[331, 413, 418, 503],
#     [501, 417, 577, 501],
#     [695, 422, 763, 487]],
#    'source_sequence': 'sala_b_540'},
#   'frame_88': {'frame_path': '../../datasets/sala_b_540/images/frame_2620.jpg',
#    'bboxes': [[410, 417, 500, 506],
#     [585, 416, 662, 504],
#     [738, 421, 810, 488]],
#    'source_sequence': 'sala_b_540'},
#   'frame_89': {'frame_path': '../../datasets/sala_b_540/images/frame_2640.jpg',
#    'bboxes': [[635, 506, 746, 634],
#     [861, 499, 993, 634],
#     [1071, 507, 1155, 598]],
#    'source_sequence': 'sala_b_540'},
#   'frame_90': {'frame_path': '../../datasets/sala_b_540/images/frame_2660.jpg',
#    'bboxes': [[516, 594, 702, 720],
#     [829, 633, 973, 720],
#     [1073, 601, 1196, 715]],
#    'source_sequence': 'sala_b_540'},
#   'frame_91': {'frame_path': '../../datasets/sala_b_540/images/frame_2680.jpg',
#    'bboxes': [[536, 602, 640, 718],
#     [754, 627, 873, 720],
#     [985, 611, 1093, 708]],
#    'source_sequence': 'sala_b_540'},
#   'frame_92': {'frame_path': '../../datasets/sala_b_540/images/frame_2700.jpg',
#    'bboxes': [[753, 631, 830, 703], [966, 621, 1051, 694]],
#    'source_sequence': 'sala_b_540'},
#   'frame_93': {'frame_path': '../../datasets/sala_b_540/images/frame_2720.jpg',
#    'bboxes': [[716, 621, 783, 689], [905, 624, 981, 681]],
#    'source_sequence': 'sala_b_540'},
#   'frame_94': {'frame_path': '../../datasets/sala_b_540/images/frame_2740.jpg',
#    'bboxes': [[445, 619, 518, 699], [763, 629, 842, 688]],
#    'source_sequence': 'sala_b_540'},
#   'frame_95': {'frame_path': '../../datasets/sala_b_540/images/frame_2760.jpg',
#    'bboxes': [[397, 613, 471, 706], [547, 629, 606, 696]],
#    'source_sequence': 'sala_b_540'},
#   'frame_96': {'frame_path': '../../datasets/sala_b_540/images/frame_2780.jpg',
#    'bboxes': [[713, 624, 784, 695], [430, 607, 584, 720]],
#    'source_sequence': 'sala_b_540'},
#   'frame_97': {'frame_path': '../../datasets/sala_b_540/images/frame_2800.jpg',
#    'bboxes': [[808, 526, 1023, 720],
#     [768, 602, 863, 717],
#     [734, 624, 795, 700]],
#    'source_sequence': 'sala_b_540'},
#   'frame_98': {'frame_path': '../../datasets/sala_b_540/images/frame_2820.jpg',
#    'bboxes': [[776, 599, 947, 720],
#     [715, 618, 792, 701],
#     [765, 595, 844, 680]],
#    'source_sequence': 'sala_b_540'},
#   'frame_99': {'frame_path': '../../datasets/sala_b_540/images/frame_2840.jpg',
#    'bboxes': [[390, 590, 488, 720],
#     [714, 621, 775, 696],
#     [741, 621, 859, 720]],
#    'source_sequence': 'sala_b_540'},
#   'frame_100': {'frame_path': '../../datasets/sala_b_734/images/frame_0020.jpg',
#    'bboxes': [[716, 620, 773, 684], [380, 607, 490, 720]],
#    'source_sequence': 'sala_b_734'},
#   'frame_101': {'frame_path': '../../datasets/sala_b_734/images/frame_0060.jpg',
#    'bboxes': [[783, 650, 824, 691],
#     [704, 634, 780, 720],
#     [501, 620, 580, 720]],
#    'source_sequence': 'sala_b_734'},
#   'frame_102': {'frame_path': '../../datasets/sala_b_734/images/frame_0080.jpg',
#    'bboxes': [[718, 637, 785, 720], [754, 644, 789, 693]],
#    'source_sequence': 'sala_b_734'},
#   'frame_103': {'frame_path': '../../datasets/sala_b_734/images/frame_0100.jpg',
#    'bboxes': [[704, 629, 755, 720], [473, 638, 623, 720]],
#    'source_sequence': 'sala_b_734'},
#   'frame_104': {'frame_path': '../../datasets/sala_b_734/images/frame_0120.jpg',
#    'bboxes': [[370, 574, 530, 720], [544, 636, 600, 720]],
#    'source_sequence': 'sala_b_734'},
#   'frame_105': {'frame_path': '../../datasets/sala_b_734/images/frame_0140.jpg',
#    'bboxes': [[742, 591, 861, 720]],
#    'source_sequence': 'sala_b_734'},
#   'frame_106': {'frame_path': '../../datasets/sala_b_734/images/frame_0160.jpg',
#    'bboxes': [[698, 606, 781, 720], [542, 617, 608, 720]],
#    'source_sequence': 'sala_b_734'},
#   'frame_107': {'frame_path': '../../datasets/sala_b_734/images/frame_0180.jpg',
#    'bboxes': [[412, 612, 512, 720], [536, 604, 624, 720]],
#    'source_sequence': 'sala_b_734'},
#   'frame_108': {'frame_path': '../../datasets/sala_b_734/images/frame_0200.jpg',
#    'bboxes': [[737, 588, 859, 720], [491, 599, 608, 720]],
#    'source_sequence': 'sala_b_734'},
#   'frame_109': {'frame_path': '../../datasets/sala_b_734/images/frame_0220.jpg',
#    'bboxes': [[769, 642, 826, 714], [904, 620, 989, 720]],
#    'source_sequence': 'sala_b_734'},
#   'frame_110': {'frame_path': '../../datasets/sala_b_734/images/frame_0240.jpg',
#    'bboxes': [[263, 594, 382, 720], [523, 626, 588, 720]],
#    'source_sequence': 'sala_b_734'},
#   'frame_111': {'frame_path': '../../datasets/sala_b_734/images/frame_0280.jpg',
#    'bboxes': [[390, 362, 577, 588],
#     [713, 368, 763, 433],
#     [809, 367, 865, 419]],
#    'source_sequence': 'sala_b_734'},
#   'frame_112': {'frame_path': '../../datasets/sala_b_734/images/frame_0300.jpg',
#    'bboxes': [[568, 348, 680, 471],
#     [811, 358, 881, 441],
#     [966, 313, 1152, 565],
#     [909, 369, 972, 426]],
#    'source_sequence': 'sala_b_734'},
#   'frame_113': {'frame_path': '../../datasets/sala_b_734/images/frame_0320.jpg',
#    'bboxes': [[460, 338, 613, 492],
#     [733, 310, 955, 575],
#     [956, 364, 1044, 439]],
#    'source_sequence': 'sala_b_734'},
#   'frame_114': {'frame_path': '../../datasets/sala_b_734/images/frame_0340.jpg',
#    'bboxes': [[212, 309, 446, 538],
#     [372, 328, 529, 501],
#     [597, 356, 678, 462],
#     [924, 357, 1040, 452]],
#    'source_sequence': 'sala_b_734'},
#   'frame_115': {'frame_path': '../../datasets/sala_b_734/images/frame_0360.jpg',
#    'bboxes': [[39, 306, 287, 567],
#     [295, 319, 469, 543],
#     [708, 359, 785, 457],
#     [875, 357, 982, 449]],
#    'source_sequence': 'sala_b_734'},
#   'frame_116': {'frame_path': '../../datasets/sala_b_734/images/frame_0380.jpg',
#    'bboxes': [[94, 325, 355, 532],
#     [544, 297, 818, 623],
#     [829, 354, 914, 454],
#     [1016, 359, 1140, 455]],
#    'source_sequence': 'sala_b_734'},
#   'frame_117': {'frame_path': '../../datasets/sala_b_734/images/frame_0400.jpg',
#    'bboxes': [[699, 309, 966, 606],
#     [1008, 362, 1091, 443],
#     [460, 354, 560, 457],
#     [478, 361, 606, 481]],
#    'source_sequence': 'sala_b_734'},
#   'frame_118': {'frame_path': '../../datasets/sala_b_734/images/frame_0420.jpg',
#    'bboxes': [[571, 344, 709, 518],
#     [811, 360, 878, 442],
#     [567, 354, 654, 449]],
#    'source_sequence': 'sala_b_734'},
#   'frame_119': {'frame_path': '../../datasets/sala_b_734/images/frame_0440.jpg',
#    'bboxes': [[442, 297, 683, 610],
#     [641, 342, 776, 490],
#     [783, 351, 863, 458],
#     [817, 344, 1012, 551],
#     [1215, 359, 1280, 457]],
#    'source_sequence': 'sala_b_734'},
#   'frame_120': {'frame_path': '../../datasets/sala_b_734/images/frame_0460.jpg',
#    'bboxes': [[908, 335, 1226, 615], [734, 328, 944, 548]],
#    'source_sequence': 'sala_b_734'},
#   'frame_121': {'frame_path': '../../datasets/sala_b_734/images/frame_0480.jpg',
#    'bboxes': [[1081, 347, 1280, 590], [1061, 352, 1221, 488]],
#    'source_sequence': 'sala_b_734'},
#   'frame_122': {'frame_path': '../../datasets/sala_b_734/images/frame_0500.jpg',
#    'bboxes': [[593, 328, 971, 713], [176, 341, 557, 686]],
#    'source_sequence': 'sala_b_734'},
#   'frame_123': {'frame_path': '../../datasets/sala_b_734/images/frame_0520.jpg',
#    'bboxes': [[67, 303, 255, 513], [300, 265, 1038, 720]],
#    'source_sequence': 'sala_b_734'},
#   'frame_124': {'frame_path': '../../datasets/sala_b_734/images/frame_0540.jpg',
#    'bboxes': [[257, 299, 473, 528],
#     [1048, 268, 1280, 628],
#     [822, 348, 901, 425]],
#    'source_sequence': 'sala_b_734'},
#   'frame_125': {'frame_path': '../../datasets/sala_b_734/images/frame_0560.jpg',
#    'bboxes': [[205, 317, 387, 503],
#     [954, 280, 1231, 548],
#     [893, 333, 968, 408]],
#    'source_sequence': 'sala_b_734'},
#   'frame_126': {'frame_path': '../../datasets/sala_b_734/images/frame_0580.jpg',
#    'bboxes': [[511, 330, 638, 455],
#     [534, 305, 931, 694],
#     [964, 357, 1036, 409],
#     [1147, 310, 1280, 520]],
#    'source_sequence': 'sala_b_734'},
#   'frame_127': {'frame_path': '../../datasets/sala_b_734/images/frame_0600.jpg',
#    'bboxes': [[131, 305, 416, 655],
#     [83, 370, 245, 493],
#     [924, 359, 1078, 497]],
#    'source_sequence': 'sala_b_734'},
#   'frame_128': {'frame_path': '../../datasets/sala_b_734/images/frame_0620.jpg',
#    'bboxes': [[25, 320, 177, 562], [1048, 368, 1174, 484]],
#    'source_sequence': 'sala_b_734'},
#   'frame_129': {'frame_path': '../../datasets/sala_b_734/images/frame_0640.jpg',
#    'bboxes': [[140, 366, 291, 493], [1008, 369, 1119, 466]],
#    'source_sequence': 'sala_b_734'},
#   'frame_130': {'frame_path': '../../datasets/sala_b_734/images/frame_0660.jpg',
#    'bboxes': [[176, 358, 337, 502],
#     [1033, 373, 1136, 463],
#     [1206, 365, 1280, 481]],
#    'source_sequence': 'sala_b_734'},
#   'frame_131': {'frame_path': '../../datasets/sala_b_734/images/frame_0680.jpg',
#    'bboxes': [[273, 356, 420, 504],
#     [1204, 362, 1280, 499],
#     [1136, 381, 1227, 449]],
#    'source_sequence': 'sala_b_734'},
#   'frame_132': {'frame_path': '../../datasets/sala_b_734/images/frame_0700.jpg',
#    'bboxes': [[363, 367, 486, 493],
#     [1090, 352, 1280, 533],
#     [1132, 382, 1200, 447]],
#    'source_sequence': 'sala_b_734'},
#   'frame_133': {'frame_path': '../../datasets/sala_b_734/images/frame_0720.jpg',
#    'bboxes': [[417, 379, 523, 482], [701, 385, 904, 562]],
#    'source_sequence': 'sala_b_734'},
#   'frame_134': {'frame_path': '../../datasets/sala_b_734/images/frame_0740.jpg',
#    'bboxes': [[532, 363, 698, 516], [453, 382, 568, 492]],
#    'source_sequence': 'sala_b_734'},
#   'frame_135': {'frame_path': '../../datasets/sala_b_734/images/frame_0760.jpg',
#    'bboxes': [[293, 381, 454, 523], [591, 391, 709, 488]],
#    'source_sequence': 'sala_b_734'},
#   'frame_136': {'frame_path': '../../datasets/sala_b_734/images/frame_0780.jpg',
#    'bboxes': [[304, 373, 415, 508],
#     [819, 383, 942, 484],
#     [1137, 392, 1221, 460]],
#    'source_sequence': 'sala_b_734'},
#   'frame_137': {'frame_path': '../../datasets/sala_b_734/images/frame_0820.jpg',
#    'bboxes': [[54, 290, 168, 384], [709, 289, 822, 384], [801, 294, 903, 370]],
#    'source_sequence': 'sala_b_734'},
#   'frame_138': {'frame_path': '../../datasets/sala_b_734/images/frame_0840.jpg',
#    'bboxes': [[33, 279, 156, 383],
#     [533, 288, 667, 398],
#     [650, 293, 742, 372],
#     [992, 298, 1030, 342]],
#    'source_sequence': 'sala_b_734'},
#   'frame_139': {'frame_path': '../../datasets/sala_b_734/images/frame_0860.jpg',
#    'bboxes': [[88, 288, 185, 380],
#     [397, 278, 511, 388],
#     [552, 281, 651, 378],
#     [984, 298, 1023, 343]],
#    'source_sequence': 'sala_b_734'},
#   'frame_140': {'frame_path': '../../datasets/sala_b_734/images/frame_0880.jpg',
#    'bboxes': [[64, 287, 155, 375],
#     [362, 274, 507, 405],
#     [627, 267, 775, 419],
#     [974, 302, 1032, 352]],
#    'source_sequence': 'sala_b_734'},
#   'frame_141': {'frame_path': '../../datasets/sala_b_734/images/frame_0900.jpg',
#    'bboxes': [[31, 294, 99, 373],
#     [1, 290, 37, 379],
#     [96, 295, 264, 423],
#     [482, 240, 691, 473],
#     [973, 296, 1030, 356]],
#    'source_sequence': 'sala_b_734'},
#   'frame_142': {'frame_path': '../../datasets/sala_b_734/images/frame_0920.jpg',
#    'bboxes': [[94, 267, 353, 526], [5, 286, 164, 457], [979, 294, 1056, 369]],
#    'source_sequence': 'sala_b_734'},
#   'frame_143': {'frame_path': '../../datasets/sala_b_734/images/frame_0940.jpg',
#    'bboxes': [[205, 551, 446, 720],
#     [1, 522, 126, 720],
#     [1036, 570, 1119, 660]],
#    'source_sequence': 'sala_b_734'},
#   'frame_144': {'frame_path': '../../datasets/sala_b_734/images/frame_0960.jpg',
#    'bboxes': [[2, 545, 112, 720], [650, 574, 795, 717]],
#    'source_sequence': 'sala_b_734'},
#   'frame_145': {'frame_path': '../../datasets/sala_b_734/images/frame_1000.jpg',
#    'bboxes': [[192, 608, 255, 685], [323, 580, 488, 720], [99, 612, 202, 720]],
#    'source_sequence': 'sala_b_734'},
#   'frame_146': {'frame_path': '../../datasets/sala_b_734/images/frame_1020.jpg',
#    'bboxes': [[193, 584, 383, 720], [423, 605, 575, 720]],
#    'source_sequence': 'sala_b_734'},
#   'frame_147': {'frame_path': '../../datasets/sala_b_734/images/frame_1040.jpg',
#    'bboxes': [[229, 561, 455, 720], [85, 593, 169, 704], [1, 591, 108, 720]],
#    'source_sequence': 'sala_b_734'},
#   'frame_148': {'frame_path': '../../datasets/sala_b_734/images/frame_1060.jpg',
#    'bboxes': [[249, 515, 492, 720], [508, 556, 691, 720]],
#    'source_sequence': 'sala_b_734'},
#   'frame_149': {'frame_path': '../../datasets/sala_b_734/images/frame_1080.jpg',
#    'bboxes': [[17, 579, 192, 720], [177, 579, 290, 720]],
#    'source_sequence': 'sala_b_734'},
#   'frame_150': {'frame_path': '../../datasets/sala_b_734/images/frame_1100.jpg',
#    'bboxes': [[5, 560, 116, 715]],
#    'source_sequence': 'sala_b_734'},
#   'frame_151': {'frame_path': '../../datasets/sala_b_734/images/frame_1120.jpg',
#    'bboxes': [[273, 504, 385, 629],
#     [537, 506, 671, 627],
#     [678, 512, 965, 720]],
#    'source_sequence': 'sala_b_734'},
#   'frame_152': {'frame_path': '../../datasets/sala_b_734/images/frame_1140.jpg',
#    'bboxes': [[428, 504, 548, 624], [593, 488, 768, 715]],
#    'source_sequence': 'sala_b_734'},
#   'frame_153': {'frame_path': '../../datasets/sala_b_734/images/frame_1160.jpg',
#    'bboxes': [[448, 415, 664, 720], [356, 503, 461, 633]],
#    'source_sequence': 'sala_b_734'},
#   'frame_154': {'frame_path': '../../datasets/sala_b_734/images/frame_1180.jpg',
#    'bboxes': [[317, 507, 414, 603], [614, 449, 904, 720]],
#    'source_sequence': 'sala_b_734'},
#   'frame_155': {'frame_path': '../../datasets/sala_b_734/images/frame_1200.jpg',
#    'bboxes': [[403, 511, 470, 593], [1018, 488, 1280, 715]],
#    'source_sequence': 'sala_b_734'},
#   'frame_156': {'frame_path': '../../datasets/sala_b_734/images/frame_1240.jpg',
#    'bboxes': [[1156, 555, 1230, 642],
#     [1030, 562, 1100, 646],
#     [691, 530, 945, 720]],
#    'source_sequence': 'sala_b_734'},
#   'frame_157': {'frame_path': '../../datasets/sala_b_734/images/frame_1260.jpg',
#    'bboxes': [[837, 561, 961, 684],
#     [1034, 564, 1096, 644],
#     [1194, 558, 1260, 632]],
#    'source_sequence': 'sala_b_734'},
#   'frame_158': {'frame_path': '../../datasets/sala_b_734/images/frame_1300.jpg',
#    'bboxes': [[444, 504, 546, 617],
#     [662, 514, 723, 586],
#     [702, 519, 752, 584]],
#    'source_sequence': 'sala_b_734'},
#   'frame_159': {'frame_path': '../../datasets/sala_b_734/images/frame_1320.jpg',
#    'bboxes': [[627, 513, 698, 602],
#     [694, 517, 766, 595],
#     [382, 524, 504, 616]],
# ...
#    'source_sequence': 'pasillo_lab_683'},
#   'frame_75': {'frame_path': '../../datasets/pasillo_lab_683/images/frame_1740.jpg',
#    'bboxes': [[738, 182, 825, 271]],
#    'source_sequence': 'pasillo_lab_683'},
#   'frame_76': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_0020.jpg',
#    'bboxes': [[461, 274, 554, 403],
#     [595, 299, 622, 347],
#     [617, 305, 654, 356],
#     [675, 307, 710, 339]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_77': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_0040.jpg',
#    'bboxes': [[415, 268, 537, 424],
#     [588, 297, 620, 350],
#     [605, 302, 653, 370],
#     [649, 309, 668, 341],
#     [669, 310, 692, 341]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_78': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_0060.jpg',
#    'bboxes': [[372, 209, 677, 588],
#     [676, 302, 773, 402],
#     [623, 307, 663, 347],
#     [660, 310, 682, 341]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_79': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_0080.jpg',
#    'bboxes': [[412, 207, 699, 567],
#     [785, 257, 949, 463],
#     [633, 307, 669, 350],
#     [654, 307, 682, 344]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_80': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_0100.jpg',
#    'bboxes': [[407, 270, 737, 586], [1, 243, 193, 492]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_81': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_0120.jpg',
#    'bboxes': [[187, 250, 369, 444], [263, 169, 682, 674]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_82': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_0140.jpg',
#    'bboxes': [[643, 302, 711, 400],
#     [671, 269, 792, 433],
#     [761, 305, 789, 344]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_83': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_0160.jpg',
#    'bboxes': [[672, 284, 751, 396],
#     [636, 310, 683, 375],
#     [736, 307, 777, 346]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_84': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_0180.jpg',
#    'bboxes': [[622, 301, 680, 372],
#     [709, 305, 783, 386],
#     [762, 302, 802, 353]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_85': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_0200.jpg',
#    'bboxes': [[455, 146, 531, 235],
#     [634, 116, 761, 277],
#     [567, 157, 609, 208],
#     [619, 159, 661, 210]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_86': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_0220.jpg',
#    'bboxes': [[542, 160, 609, 228],
#     [603, 170, 643, 204],
#     [676, 158, 725, 215],
#     [937, 94, 1206, 342],
#     [534, 164, 557, 210]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_87': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_0240.jpg',
#    'bboxes': [[492, 150, 546, 227],
#     [549, 162, 616, 235],
#     [689, 162, 728, 212],
#     [719, 159, 773, 217]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_88': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_0260.jpg',
#    'bboxes': [[442, 147, 534, 244],
#     [582, 158, 654, 244],
#     [709, 156, 764, 225]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_89': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_0280.jpg',
#    'bboxes': [[536, 137, 631, 264],
#     [665, 155, 717, 229],
#     [349, 116, 529, 299],
#     [483, 170, 529, 226]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_90': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_0300.jpg',
#    'bboxes': [[2, 74, 210, 444],
#     [175, 122, 361, 297],
#     [453, 164, 497, 225],
#     [498, 159, 567, 225]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_91': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_0320.jpg',
#    'bboxes': [[295, 134, 436, 277], [454, 79, 872, 546], [514, 156, 557, 227]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_92': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_0340.jpg',
#    'bboxes': [[453, 154, 556, 264],
#     [515, 170, 569, 216],
#     [586, 164, 641, 222]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_93': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_0360.jpg',
#    'bboxes': [[543, 150, 628, 248],
#     [635, 163, 699, 225],
#     [503, 175, 547, 221],
#     [2, 249, 350, 720]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_94': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_0380.jpg',
#    'bboxes': [[447, 173, 502, 233],
#     [549, 144, 630, 265],
#     [651, 159, 725, 230]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_95': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_0440.jpg',
#    'bboxes': [[929, 113, 1250, 414]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_96': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_0500.jpg',
#    'bboxes': [[320, 479, 365, 527],
#     [382, 481, 425, 537],
#     [479, 477, 549, 556]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_97': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_0520.jpg',
#    'bboxes': [[696, 242, 746, 295],
#     [762, 239, 817, 305],
#     [818, 215, 922, 316],
#     [807, 244, 862, 296]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_98': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_0540.jpg',
#    'bboxes': [[639, 229, 702, 308],
#     [696, 241, 727, 277],
#     [796, 233, 837, 296],
#     [783, 200, 935, 354]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_99': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_0560.jpg',
#    'bboxes': [[583, 214, 662, 323],
#     [756, 232, 788, 282],
#     [746, 158, 1020, 426]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_100': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_0580.jpg',
#    'bboxes': [[464, 215, 562, 330],
#     [613, 225, 668, 303],
#     [711, 242, 742, 277],
#     [805, 235, 852, 294],
#     [843, 139, 1230, 534]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_101': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_0600.jpg',
#    'bboxes': [[489, 217, 572, 314],
#     [687, 184, 847, 384],
#     [823, 232, 862, 285],
#     [705, 238, 742, 290]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_102': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_0620.jpg',
#    'bboxes': [[387, 188, 561, 378],
#     [722, 229, 782, 306],
#     [846, 233, 897, 293]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_103': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_0640.jpg',
#    'bboxes': [[597, 236, 791, 439],
#     [806, 241, 1019, 453],
#     [1032, 274, 1149, 398],
#     [1176, 292, 1232, 357]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_104': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_0660.jpg',
#    'bboxes': [[802, 262, 1010, 414],
#     [983, 290, 1151, 450],
#     [1184, 300, 1280, 383],
#     [1069, 294, 1183, 348]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_105': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_0680.jpg',
#    'bboxes': [[516, 220, 594, 322],
#     [392, 237, 442, 293],
#     [121, 176, 353, 405],
#     [1, 177, 144, 394],
#     [143, 217, 215, 326]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_106': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_0700.jpg',
#    'bboxes': [[1, 173, 252, 421],
#     [250, 174, 432, 412],
#     [471, 238, 523, 299],
#     [640, 221, 731, 326]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_107': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_0720.jpg',
#    'bboxes': [[396, 145, 696, 453],
#     [698, 157, 903, 446],
#     [811, 217, 904, 334]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_108': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_0740.jpg',
#    'bboxes': [[1, 218, 197, 474],
#     [398, 176, 606, 463],
#     [622, 211, 714, 339],
#     [422, 243, 452, 288]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_109': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_0760.jpg',
#    'bboxes': [[3, 203, 211, 410], [502, 240, 552, 303], [619, 196, 763, 372]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_110': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_0780.jpg',
#    'bboxes': [[312, 182, 541, 405],
#     [537, 243, 566, 282],
#     [552, 245, 609, 300],
#     [667, 237, 716, 295],
#     [802, 207, 941, 355]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_111': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_0800.jpg',
#    'bboxes': [[514, 231, 580, 313],
#     [560, 244, 591, 288],
#     [671, 238, 722, 297],
#     [698, 199, 844, 377]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_112': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_0820.jpg',
#    'bboxes': [[113, 175, 340, 408],
#     [396, 238, 488, 336],
#     [513, 249, 558, 292],
#     [572, 246, 614, 302]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_113': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_0840.jpg',
#    'bboxes': [[2, 161, 224, 464],
#     [200, 185, 368, 415],
#     [454, 243, 489, 290],
#     [490, 244, 531, 300]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_114': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_0860.jpg',
#    'bboxes': [[1, 111, 408, 720], [446, 250, 487, 290], [496, 247, 536, 297]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_115': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_0880.jpg',
#    'bboxes': [[450, 250, 483, 288], [486, 251, 525, 294], [1, 140, 385, 720]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_116': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_0900.jpg',
#    'bboxes': [[5, 111, 345, 567], [436, 248, 469, 286], [476, 251, 510, 297]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_117': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_0920.jpg',
#    'bboxes': [[516, 167, 683, 383],
#     [688, 227, 724, 273],
#     [763, 235, 800, 279]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_118': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_0940.jpg',
#    'bboxes': [[619, 191, 727, 340], [774, 230, 812, 279]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_119': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_0960.jpg',
#    'bboxes': [[647, 224, 688, 279],
#     [716, 219, 807, 329],
#     [806, 227, 847, 279]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_120': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_0980.jpg',
#    'bboxes': [[640, 219, 684, 282],
#     [710, 210, 789, 312],
#     [816, 224, 861, 282]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_121': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_1000.jpg',
#    'bboxes': [[664, 218, 714, 286],
#     [743, 224, 806, 297],
#     [820, 226, 864, 281]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_122': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_1020.jpg',
#    'bboxes': [[649, 213, 711, 292],
#     [744, 230, 796, 288],
#     [800, 226, 846, 277]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_123': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_1040.jpg',
#    'bboxes': [[581, 207, 662, 309],
#     [711, 217, 766, 281],
#     [789, 224, 822, 272]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_124': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_1060.jpg',
#    'bboxes': [[570, 193, 671, 327],
#     [720, 223, 769, 272],
#     [796, 231, 820, 268]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_125': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_1080.jpg',
#    'bboxes': [[454, 173, 622, 367],
#     [692, 223, 737, 272],
#     [806, 228, 834, 267]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_126': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_1100.jpg',
#    'bboxes': [[1, 144, 402, 720], [688, 224, 730, 268], [799, 229, 827, 265]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_127': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_1120.jpg',
#    'bboxes': [[689, 220, 731, 272], [808, 230, 834, 264]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_128': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_1140.jpg',
#    'bboxes': [[468, 221, 508, 265], [599, 226, 625, 256]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_129': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_1160.jpg',
#    'bboxes': [[520, 221, 561, 268], [611, 224, 640, 254]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_130': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_1180.jpg',
#    'bboxes': [[529, 224, 583, 276], [614, 228, 643, 259]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_131': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_1200.jpg',
#    'bboxes': [[523, 222, 577, 282], [610, 224, 646, 258]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_132': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_1220.jpg',
#    'bboxes': [[720, 211, 782, 293], [913, 232, 944, 273]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_133': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_1240.jpg',
#    'bboxes': [[709, 224, 804, 328], [962, 251, 1016, 297]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_134': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_1260.jpg',
#    'bboxes': [[750, 218, 849, 334], [956, 238, 1019, 299]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_135': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_1280.jpg',
#    'bboxes': [[1077, 191, 1218, 330]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_136': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_1300.jpg',
#    'bboxes': [[842, 144, 1280, 643], [528, 215, 625, 275]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_137': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_1320.jpg',
#    'bboxes': [[555, 232, 611, 300], [662, 215, 744, 321]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_138': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_1340.jpg',
#    'bboxes': [[564, 234, 619, 299], [624, 224, 716, 330]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_139': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_1360.jpg',
#    'bboxes': [[561, 223, 611, 289], [565, 217, 651, 324]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_140': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_1380.jpg',
#    'bboxes': [[565, 223, 656, 324], [562, 224, 604, 289]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_141': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_1400.jpg',
#    'bboxes': [[543, 229, 624, 322]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_142': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_1420.jpg',
#    'bboxes': [[491, 207, 563, 311]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_143': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_1440.jpg',
#    'bboxes': [[493, 204, 568, 311]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_144': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_1460.jpg',
#    'bboxes': [[492, 214, 569, 308]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_145': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_1480.jpg',
#    'bboxes': [[475, 207, 550, 310]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_146': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_1500.jpg',
#    'bboxes': [[521, 207, 587, 304]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_147': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_1540.jpg',
#    'bboxes': [[105, 277, 298, 449], [242, 313, 335, 386]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_148': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_1560.jpg',
#    'bboxes': [[650, 306, 810, 488],
#     [802, 304, 896, 410],
#     [952, 313, 1039, 389]],
#    'source_sequence': 'pasillo_lab_961'},
#   'frame_149': {'frame_path': '../../datasets/pasillo_lab_961/images/frame_1580.jpg',
#    'bboxes': [[635, 275, 768, 444],
#     [783, 313, 868, 401],
#     [954, 301, 1038, 388]],
#    'source_sequence': 'pasillo_lab_961'}}}

# %%
DATA.keys()
# Out:
# dict_keys(['sala_a', 'sala_b', 'sala_c', 'hall', 'aire_libre', 'pasillo_lab'])

# %% [markdown]
# ### Show a single frame

# %%
def show_frame(element: dict, alpha: int = 0.5):
    """Function that takes in a dictionary containing the data associated to an
    frame and its labels, and displays this information.

    :param element: dictionary containing the data associated to a frame and its labels.
    :param alpha: transparency value of the bboxes displayed.
    :return:
        None
    """
    # Load frame
    frame = cv2.imread(element['frame_path'])

    # Load bboxes
    bboxes = element['bboxes']

    # Overlay bboxes onto the frame
    for box in bboxes:
        
        # Initialize blank mask frame of the same dimensions for drawing the shapes
        shapes = np.zeros_like(frame, np.uint8)

        # Draw shapes
        cv2.rectangle(
            shapes,
            (box[0], box[1]),   # p1(x_min, y_min)
            (box[2], box[3]),   # p2(x_max, y_max)
            (255, 255, 255),    # color
            cv2.FILLED,
        )

        # Generate output by blending frame with shapes frame, using the shapes frames
        # also as mask to limit the blending to those parts
        mask = shapes.astype(bool)
        frame[mask] = cv2.addWeighted(frame, alpha, shapes, 1 - alpha, 0)[mask]

    # Show frame
    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    plt.imshow(frame)

# %%
import os
path = '../../datasets/sala_c_167/images/frame_0400.jpg'
print(os.path.exists(path))
# Out:
# True

# %%
# Show a single frame
show_frame(DATA['sala_c']['frame_20'])

# %% [markdown]
# ## Display frame distribution across scenarios

# %%
def plot_frames_distribution(data):
    """Function that takes in a dictionary containing all the information associated
    to a dataset, and displays the distribution of frames across sequences/scenarios.

    :param data: dictionary containing all the information associated to a dataset.
    :return:
        None
    """
    # Extract scenario names and their respective frame counts
    scenarios = list(data.keys())
    frame_counts = [len(data[scenario]) for scenario in scenarios]

    # Create a bar plot
    ax = plt.bar(scenarios, frame_counts, width=0.4)  # color='blue'

    # Add annotations to the bars
    for p, count in zip(ax.patches, frame_counts):
        plt.text(p.get_x() + p.get_width()/4., p.get_y() + count + 1,   # (x, y)
                 str(count),                                            # text
                 fontsize=10, fontweight='bold', color='grey')          # style

    plt.xlabel('Scenarios')
    plt.ylabel('Number of frames')
    plt.title('Distribution of frames per Scenario')
    plt.xticks(rotation=45)
    plt.ylim([0, max(frame_counts)*1.1])
    plt.tight_layout()
    # plt.savefig('frame distribution.png')
    plt.show()

# %%
# Display the frame distribution for all scenarios
plot_frames_distribution(DATA)

# %% [markdown]
# Tendríamos que juntar todos los frames que sean en un mismo escenario, no tiene sentido hacer un análisis por carpeta

# %% [markdown]
# ## Display the bbox distribution across scenarios

# %%
def plot_bboxes_distribution(data):
    """Function that takes in a dictionary containing all the information associated
    to a dataset, and displays the distribution of bboxes across sequences/scenarios.

    :param data: dictionary containing all the information associated to a dataset.
    :return:
        None
    """
    # Extract scenario names and their respective bboxes counts
    scenarios = list(data.keys())
    bboxes_counts = []
    for scenario in scenarios:
        count = 0
        for frame in data[scenario].keys():
            count += len(data[scenario][frame]['bboxes'])
        bboxes_counts.append(count)

    # Create a bar plot
    ax = plt.bar(scenarios, bboxes_counts, width=0.4)  # color='blue'

    # Add annotations to the bars
    for p, count in zip(ax.patches, bboxes_counts):
        plt.text(p.get_x() + p.get_width()/4., p.get_y() + count + 1,   # (x, y)
                 str(count),                                            # text
                 fontsize=10, fontweight='bold', color='grey')          # style

    plt.xlabel('Scenarios')
    plt.ylabel('Number of Bboxes')
    plt.title('Distribution of Bboxes per Scenario')
    plt.xticks(rotation=45)
    plt.ylim([0, max(bboxes_counts)*1.1])
    plt.tight_layout()
    # plt.savefig('Bbox distribution.png')
    plt.show()

# %%
# Display the bbox distribution for all scenarios
plot_bboxes_distribution(DATA)

# %% [markdown]
# ## Display the bbox area distribution across scenarios

# %%
def plot_bboxes_area_distribution(data: dict, bins: int = 15) -> None:
    """Function that takes in a dictionary containing all the information associated
    to a dataset, and displays the distribution of the area of bboxes across sequences/scenarios.

    :param data: dictionary containing all the information associated to a dataset.
    :param bins: number of bins to display in the histogram.
    :return:
        None
    """
    # Create a subplot with multiple histograms
    fig, axes = plt.subplots(nrows=1, ncols=len(data), figsize=(15, 5))

    # Define colors for each scenario
    colors = [
        'b', 'g', 'r', 'c', 'm',
        'tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple',
        'tab:brown', 'tab:pink', 'tab:gray', 'tab:olive', 'tab:cyan'
    ]

    # Add a title above all the subplots
    plt.suptitle('Distribution of Bboxes area per Scenario')

    for i, (scenario, frame_data) in enumerate(data.items()):
        # Calculate bounding box areas for the scenario
        bbox_areas = []
        for frame_info in frame_data.values():
            for bbox in frame_info['bboxes']:
                x_min, y_min, x_max, y_max = bbox
                area = (x_max - x_min) * (y_max - y_min) / 1_000    # divide by 1_0000 for shorter x labels
                bbox_areas.append(area)

        # Plot the histogram for the scenario
        axes[i].hist(bbox_areas, bins=bins, color=colors[i], alpha=0.7)
        axes[i].set_title(scenario)
        axes[i].set_xlabel('Bounding Box Area (x1.000)')
        axes[i].set_ylabel('Frequency')

    # Adjust the layout
    plt.tight_layout()
    # plt.savefig('Bbox area distribution.png')
    plt.show()

# %%
# Display the bbox area distribution for all scenarios
plot_bboxes_area_distribution(DATA, bins=30)

# %% [markdown]
# ## Display the RGB channel distribution across scenarios

# %%
def plot_rgb_channel_distribution(data):
    """Function that takes in a dictionary containing all the information associated
    to a dataset, and displays the distribution of the RGB frame channels across sequences/scenarios.

    :param data: dictionary containing all the information associated to a dataset.
    :return:
        None
    """
    # Create a subplot with multiple Gaussian distributions
    fig, axes = plt.subplots(nrows=1, ncols=len(data), figsize=(15, 5))

    # Add a title above all the subplots
    plt.suptitle("RGB Channel Distributions (Gaussian)")

    for i, (scenario, frame_data) in enumerate(data.items()):
        red_values = []
        green_values = []
        blue_values = []

        print(f'Sequence {i+1} ({scenario}):')
        for frame_info in tqdm(frame_data.values()):
            frame_path = frame_info['frame_path']

            # Load the frame using OpenCV
            frame = cv2.imread(frame_path)

            if frame is not None:
                # Extract RGB channels
                red_channel = frame[:, :, 2].mean()
                green_channel = frame[:, :, 1].mean()
                blue_channel = frame[:, :, 0].mean()

                # Append pixel values to the respective lists
                red_values.extend([red_channel])
                green_values.extend([green_channel])
                blue_values.extend([blue_channel])

        # Compute mean and standard deviation for each channel
        red_mean, red_std = np.mean(red_values), np.std(red_values)
        green_mean, green_std = np.mean(green_values), np.std(green_values)
        blue_mean, blue_std = np.mean(blue_values), np.std(blue_values)

        # Plot Gaussian distributions for each channel
        x = np.linspace(0, 255, 256)
        red_pdf = norm.pdf(x, red_mean, red_std)
        green_pdf = norm.pdf(x, green_mean, green_std)
        blue_pdf = norm.pdf(x, blue_mean, blue_std)

        axes[i].plot(x, red_pdf, color='red', label='Red')
        axes[i].plot(x, green_pdf, color='green', label='Green')
        axes[i].plot(x, blue_pdf, color='blue', label='Blue')
        axes[i].set_title(scenario)
        axes[i].set_xlabel("Pixel Value")
        axes[i].set_ylabel("Probability Density")
        axes[i].legend()

    # Adjust the layout
    plt.tight_layout()
    # plt.savefig('frame RGB channel distribution.png')
    plt.show()

# %%
# Display the RGB channel distribution for all scenarios
plot_rgb_channel_distribution(DATA)
# Out:
# Sequence 1 (sala_a):
# 100%|██████████| 87/87 [00:00<00:00, 145.97it/s]
# Sequence 2 (sala_b):
# 100%|██████████| 179/179 [00:01<00:00, 144.36it/s]
# Sequence 3 (sala_c):
# 100%|██████████| 273/273 [00:01<00:00, 146.56it/s]
# Sequence 4 (hall):
# 100%|██████████| 172/172 [00:01<00:00, 140.12it/s]
# Sequence 5 (aire_libre):
# 100%|██████████| 320/320 [00:02<00:00, 124.04it/s]
# Sequence 6 (pasillo_lab):
# 100%|██████████| 149/149 [00:00<00:00, 154.69it/s]

# %% [markdown]
# # Distribución de detecciones por escenario

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# 🎨 Estilo visual elegante
sns.set_style("white")
sns.set_context("talk", font_scale=0.9)

def plot_bbox_heatmap(scene_data, bins_x=30, bins_y=20, img_size=(1280, 720)):
    """
    Devuelve el mapa de calor NORMALIZADO (probabilidad relativa)
    de densidad de bounding boxes.
    """
    all_centers = []

    for frame_id, frame_info in scene_data.items():
        for (x1, y1, x2, y2) in frame_info['bboxes']:
            cx = (x1 + x2) / 2
            cy = (y1 + y2) / 2
            all_centers.append([cx, cy])

    if not all_centers:
        return np.zeros((bins_y, bins_x))

    centers = np.array(all_centers)
    heatmap, _, _ = np.histogram2d(
        centers[:, 0], centers[:, 1],
        bins=[bins_x, bins_y],
        range=[[0, img_size[0]], [0, img_size[1]]]
    )

    # Normalizar a probabilidad (suma total = 1)
    heatmap = heatmap / np.sum(heatmap) if np.sum(heatmap) > 0 else heatmap
    return heatmap.T


# Crear figura 3x2
fig, axes = plt.subplots(3, 2, figsize=(14, 9))
axes = axes.flatten()

# Calcular rango común
heatmaps = [plot_bbox_heatmap(DATA[e]) for e in list(DATA.keys())[:6]]
max_density = max(hm.max() for hm in heatmaps)

# Dibujar subplots
for i, (escenario, hm) in enumerate(zip(list(DATA.keys())[:6], heatmaps)):
    sns.heatmap(
        hm,
        cmap="YlOrRd",
        ax=axes[i],
        cbar=False,
        square=True,
        xticklabels=False,
        yticklabels=False,
        vmin=0,
        vmax=max_density
    )
    axes[i].set_title(escenario.replace("_", " ").title(), fontsize=13, weight="bold")
    axes[i].set_xticks([])
    axes[i].set_yticks([])
    axes[i].set_facecolor("white")

# Eliminar ejes vacíos si hay menos de 6
for j in range(i + 1, 6):
    fig.delaxes(axes[j])

# ✅ Crear barra de color desplazada a la derecha
norm = plt.Normalize(vmin=0, vmax=max_density)
sm = plt.cm.ScalarMappable(cmap="YlOrRd", norm=norm)
sm.set_array([])

# 🔹 Ajustar posición: más a la derecha con pad y fraction
cbar = fig.colorbar(
    sm,
    ax=axes,
    orientation="vertical",
    fraction=0.025,  # ancho más fino
    pad=0.08,        # más separación a la derecha
    anchor=(1.0, 0.5)  # centrado verticalmente
)
cbar.set_label("Probabilidad relativa", fontsize=11)
cbar.ax.tick_params(labelsize=10)

# Ajustes finales
plt.subplots_adjust(wspace=0.05, hspace=0.15, right=0.78)
fig.suptitle("Distribución Probabilística de Detecciones por Escenario", fontsize=16, weight="bold")
sns.despine(left=True, bottom=True)
plt.show()

# %% [markdown]
# ## Robots por frame

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")
sns.set_context("talk", font_scale=0.9)

def calcular_bboxes_por_frame(scene_data):
    """
    Calcula la media de número de bounding boxes por frame en un escenario.
    """
    conteos = []

    for frame_id, frame_info in scene_data.items():
        bboxes = frame_info.get("bboxes", [])
        conteos.append(len(bboxes))

    if len(conteos) == 0:
        return np.nan
    return np.mean(conteos)


# 🔹 Calcular la media de bboxes por frame para cada escenario
stats_bboxes = []
for escenario in DATA.keys():
    media_bboxes = calcular_bboxes_por_frame(DATA[escenario])
    stats_bboxes.append({
        "Escenario": escenario.replace("_", " ").title(),
        "Media de BBoxes por Frame": media_bboxes
    })

df_bboxes = pd.DataFrame(stats_bboxes).dropna()

# 🔹 Graficar resultados
plt.figure(figsize=(10, 6))
sns.barplot(
    data=df_bboxes,
    x="Escenario",
    y="Media de BBoxes por Frame",
    palette="YlOrRd",
    edgecolor="black"
)

plt.title("Media de Bounding Boxes por Frame por Escenario", fontsize=16, weight="bold")
plt.ylabel("Media de BBoxes por frame")
plt.xlabel("")
plt.xticks(rotation=25, ha="right")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_1797/2953753836.py:37: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("white")
sns.set_context("talk", font_scale=0.9)

def analizar_textura_frame(scene_data, frame_id=None):
    """
    Analiza la textura de un frame (Laplaciano) aplicando logaritmo
    para resaltar diferencias suaves.
    """
    # Seleccionar un frame representativo
    if frame_id is None:
        frame_id = list(scene_data.keys())[34]
    frame_info = scene_data[frame_id]

    frame_path = frame_info.get('frame_path', None)

    frame = cv2.imread(frame_path)
    
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Calcular textura con Laplaciano
    lap = cv2.Laplacian(gray, cv2.CV_64F)
    abs_lap = np.abs(lap)

    # Aplicar log para mejorar contraste de detalles
    log_lap = np.log1p(abs_lap)  # log(1 + valor) evita log(0)

    # Crear máscara de bounding boxes
    mask = np.zeros_like(gray, dtype=bool)
    for (x1, y1, x2, y2) in frame_info.get('bboxes', []):
        mask[int(y1):int(y2), int(x1):int(x2)] = True

    return {
        "frame": frame,
        "log_lap": log_lap,
        "mask": mask
    }


# 🔹 Analizar un frame por escenario
for escenario in list(DATA.keys())[:6]:
    resultado = analizar_textura_frame(DATA[escenario])
    if resultado is None:
        continue

    frame = resultado["frame"]
    log_lap = resultado["log_lap"]
    mask = resultado["mask"]

    # Visualización: frame original + mapa logarítmico de textura
    fig, axs = plt.subplots(1, 2, figsize=(14, 5))
    fig.suptitle(f"Análisis de Textura Logarítmica - {escenario.replace('_',' ').title()}",
                 fontsize=16, weight="bold")

    # 1️⃣ Frame original
    axs[0].imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
    axs[0].set_title("Frame Original")
    axs[0].axis("off")

    # 2️⃣ Mapa logarítmico de textura
    axs[1].imshow(log_lap, cmap="magma")
    axs[1].set_title("Mapa de Textura")
    axs[1].axis("off")

    # Dibujar bounding boxes
    for (x1, y1, x2, y2) in DATA[escenario][list(DATA[escenario].keys())[34]]["bboxes"]:
        rect = plt.Rectangle((x1, y1), x2-x1, y2-y1, edgecolor="cyan", facecolor="none", lw=2)
        axs[1].add_patch(rect)

    plt.tight_layout()
    plt.show()
